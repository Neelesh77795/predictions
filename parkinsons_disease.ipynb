# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
parkinsons_data = pd.read_csv("/Users/neeleshsuragani/Documents/predictions/datasets/parkinsons.csv")

# %%
parkinsons_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
parkinsons_data.shape
# Out:
# (195, 24)

# %%
parkinsons_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
#  16  HNR               195 non-null    float64
#  17  status            195 non-null    int64
#  18  RPDE              195 non-null    float64
#  19  DFA               195 non-null    float64
#  20  spread1           195 non-null    float64
#  21  spread2           195 non-null    float64
#  22  D2                195 non-null    float64
#  23  PPE               195 non-null    float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 36.7+ KB

# %%
parkinsons_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
parkinsons_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# 25%            0.000020    0.001660    0.001860    0.004985      0.016505
# 50%            0.000030    0.002500    0.002690    0.007490      0.022970
# 75%            0.000060    0.003835    0.003955    0.011505      0.037885
# max            0.000260    0.021440    0.019580    0.064330      0.119080
#
#        MDVP:Shimmer(dB)  ...  Shimmer:DDA         NHR         HNR      status  \
# count        195.000000  ...   195.000000  195.000000  195.000000  195.000000
# mean           0.282251  ...     0.046993    0.024847   21.885974    0.753846
# std            0.194877  ...     0.030459    0.040418    4.425764    0.431878
# min            0.085000  ...     0.013640    0.000650    8.441000    0.000000
# 25%            0.148500  ...     0.024735    0.005925   19.198000    1.000000
# 50%            0.221000  ...     0.038360    0.011660   22.085000    1.000000
# 75%            0.350000  ...     0.060795    0.025640   25.075500    1.000000
# max            1.302000  ...     0.169420    0.314820   33.047000    1.000000
#
#              RPDE         DFA     spread1     spread2          D2         PPE
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     0.498536    0.718099   -5.684397    0.226510    2.381826    0.206552
# std      0.103942    0.055336    1.090208    0.083406    0.382799    0.090119
# min      0.256570    0.574282   -7.964984    0.006274    1.423287    0.044539
# 25%      0.421306    0.674758   -6.450096    0.174351    2.099125    0.137451
# 50%      0.495954    0.722254   -5.720868    0.218885    2.361532    0.194052
# 75%      0.587562    0.761881   -5.046192    0.279234    2.636456    0.252980
# max      0.685151    0.825288   -2.434031    0.450493    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
parkinsons_data['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
parkinsons_data.groupby('status').mean(numeric_only=True)
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
x = parkinsons_data.drop(columns=['name','status'], axis=1)
y = parkinsons_data['status']

# %%
print(x)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# 2             0.00009   0.00544   0.00781     0.01633       0.05233
# 3             0.00009   0.00502   0.00698     0.01505       0.05492
# 4             0.00011   0.00655   0.00908     0.01966       0.06425
# ..                ...       ...       ...         ...           ...
# 190           0.00003   0.00263   0.00259     0.00790       0.04087
# 191           0.00003   0.00331   0.00292     0.00994       0.02751
# 192           0.00008   0.00624   0.00564     0.01873       0.02308
# 193           0.00004   0.00370   0.00390     0.01109       0.02296
# 194           0.00003   0.00295   0.00317     0.00885       0.01884
#
#      MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE  \
# 0               0.426  ...   0.02971      0.06545  0.02211  21.033  0.414783
# 1               0.626  ...   0.04368      0.09403  0.01929  19.085  0.458359
# 2               0.482  ...   0.03590      0.08270  0.01309  20.651  0.429895
# 3               0.517  ...   0.03772      0.08771  0.01353  20.644  0.434969
# 4               0.584  ...   0.04465      0.10470  0.01767  19.649  0.417356
# ..                ...  ...       ...          ...      ...     ...       ...
# 190             0.405  ...   0.02745      0.07008  0.02764  19.517  0.448439
# 191             0.263  ...   0.01879      0.04812  0.01810  19.147  0.431674
# 192             0.256  ...   0.01667      0.03804  0.10715  17.883  0.407567
# 193             0.241  ...   0.01588      0.03794  0.07223  19.020  0.451221
# 194             0.190  ...   0.01373      0.03078  0.04398  21.209  0.462803
#
#           DFA   spread1   spread2        D2       PPE
# 0    0.815285 -4.813031  0.266482  2.301442  0.284654
# 1    0.819521 -4.075192  0.335590  2.486855  0.368674
# 2    0.825288 -4.443179  0.311173  2.342259  0.332634
# 3    0.819235 -4.117501  0.334147  2.405554  0.368975
# 4    0.823484 -3.747787  0.234513  2.332180  0.410335
# ..        ...       ...       ...       ...       ...
# 190  0.657899 -6.538586  0.121952  2.657476  0.133050
# 191  0.683244 -6.195325  0.129303  2.784312  0.168895
# 192  0.655683 -6.787197  0.158453  2.679772  0.131728
# 193  0.643956 -6.744577  0.207454  2.138608  0.123306
# 194  0.664357 -5.724056  0.190667  2.555477  0.148569
#
# [195 rows x 22 columns]

# %%
print(y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %%
scaler = StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(x_train)

X_test = scaler.transform(x_test)

# %%
print(X_train)
# Out:
# [[-0.80172872 -0.70830513 -0.10603303 ...  0.89854281 -0.48294197
#    1.64980971]
#  [-1.04374224 -0.74950432 -0.29919921 ...  1.17531845  0.65177741
#    0.26864313]
#  [-0.3790498   0.13122544 -0.82039362 ... -0.7771489  -0.73102398
#    0.28542547]
#  ...
#  [-0.13744368 -0.31583967  0.56292775 ... -1.65126173 -0.08248373
#   -0.17764131]
#  [-0.14053505 -0.42034011  0.39263744 ...  0.19569946  1.19665768
#   -0.11105606]
#  [-0.35427092  4.57536567 -1.22354854 ...  0.55494177  0.80279984
#    2.57800238]]

# %%
model = svm.SVC(kernel='linear')

# %%
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=model.predict(x_train)

# %%
print(accuracy_score(y_train,y_pred))
# Out:
# 0.8653846153846154

# %%
y_pred=model.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8717948717948718

# %%
input_data = (197.07600,206.89600,192.05500,0.00289,0.00001,0.00166,0.00168,0.00498,0.01098,0.09700,0.00563,0.00680,0.00802,0.01689,0.00339,26.77500,0.422229,0.741367,-7.348300,0.177551,1.743867,0.085569)

input_data_as_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

std_data = scaler.transform(input_data_reshaped)

prediction = model.predict(std_data)
print(prediction)

if (prediction[0] == 0):
  print("The Person does not have Parkinsons Disease")

else:
  print("The Person has Parkinsons")
# Out:
# [1]
# The Person has Parkinsons
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename='parkinsons_disease_model.sav'
pickle.dump(model,open(filename,'wb'))

# %%
load_model=pickle.load(open('parkinsons_disease_model.sav','rb'))

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.42.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.5.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: packaging<25,>=20 in /Users/neeleshsuragani/Library/Python/3.13/lib/python/site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit) (11.1.0)
# Collecting protobuf<6,>=3.20 (from streamlit)
#   Downloading protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-19.0.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting requests<3,>=2.27 (from streamlit)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions<5,>=4.4.0 (from streamlit)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/neeleshsuragani/Library/Python/3.13/lib/python/site-packages (from streamlit) (6.4.2)
# Collecting jinja2 (from altair<6,>=4.0->streamlit)
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.25.2-py3-none-any.whl.metadata (10 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/neeleshsuragani/Library/Python/3.13/lib/python/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.27->streamlit)
#   Downloading charset_normalizer-3.4.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.27->streamlit)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.27->streamlit)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.27->streamlit)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/neeleshsuragani/Library/Python/3.13/lib/python/site-packages (from rich<14,>=10.14.0->streamlit) (2.19.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->altair<6,>=4.0->streamlit)
#   Downloading MarkupSafe-3.0.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting attrs>=22.2.0 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading rpds_py-0.22.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in /Users/neeleshsuragani/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.42.0-py2.py3-none-any.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 8.5 MB/s eta 0:00:00a 0:00:01
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 kB 3.2 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-5.5.1-py3-none-any.whl (9.5 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
# Downloading pyarrow-19.0.0-cp313-cp313-macosx_12_0_arm64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 9.9 MB/s eta 0:00:00:00:0100:01
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 9.9 MB/s eta 0:00:00ta 0:00:01
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp313-cp313-macosx_10_13_universal2.whl (195 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading narwhals-1.25.2-py3-none-any.whl (305 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading MarkupSafe-3.0.2-cp313-cp313-macosx_11_0_arm64.whl (12 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.22.3-cp313-cp313-macosx_11_0_arm64.whl (341 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: urllib3, typing-extensions, toml, tenacity, smmap, rpds-py, pyarrow, protobuf, narwhals, mdurl, MarkupSafe, idna, click, charset-normalizer, certifi, cachetools, blinker, attrs, requests, referencing, markdown-it-py, jinja2, gitdb, rich, pydeck, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
# Successfully installed MarkupSafe-3.0.2 altair-5.5.0 attrs-25.1.0 blinker-1.9.0 cachetools-5.5.1 certifi-2025.1.31 charset-normalizer-3.4.1 click-8.1.8 gitdb-4.0.12 gitpython-3.1.44 idna-3.10 jinja2-3.1.5 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 markdown-it-py-3.0.0 mdurl-0.1.2 narwhals-1.25.2 protobuf-5.29.3 pyarrow-19.0.0 pydeck-0.9.1 referencing-0.36.2 requests-2.32.3 rich-13.9.4 rpds-py-0.22.3 smmap-5.0.2 streamlit-1.42.0 tenacity-9.0.0 toml-0.10.2 typing-extensions-4.12.2 urllib3-2.3.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit-option-menu
# Out:
# Collecting streamlit-option-menu
#   Downloading streamlit_option_menu-0.4.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: streamlit>=1.36 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit-option-menu) (1.42.0)
# Requirement already satisfied: altair<6,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (2.2.2)
# Requirement already satisfied: packaging<25,>=20 in /Users/neeleshsuragani/Library/Python/3.13/lib/python/site-packages (from streamlit>=1.36->streamlit-option-menu) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from streamlit>=1.36->streamlit-option-menu) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/neeleshsuragani/Library/Python/3.13/lib/python/site-packages (from streamlit>=1.36->streamlit-option-menu) (6.4.2)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (1.25.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.36->streamlit-option-menu) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/neeleshsuragani/Library/Python/3.13/lib/python/site-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich<14,>=10.14.0->streamlit>=1.36->streamlit-option-menu) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/neeleshsuragani/Library/Python/3.13/lib/python/site-packages (from rich<14,>=10.14.0->streamlit>=1.36->streamlit-option-menu) (2.19.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.36->streamlit-option-menu) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.36->streamlit-option-menu) (0.1.2)
# Requirement already satisfied: six>=1.5 in /Users/neeleshsuragani/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (1.17.0)
# Downloading streamlit_option_menu-0.4.0-py3-none-any.whl (829 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.3/829.3 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: streamlit-option-menu
# Successfully installed streamlit-option-menu-0.4.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
